# %% [markdown]
# <a href="https://colab.research.google.com/github/yal521/DSCI441-machine-learning-project/blob/main/Get_sample_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This Get_sample_data.ipynb is used for randomly selecting a subset of dataset1_creditcard.csv because dataset1_creditcard.csv is too big to be uploaded in the GitHub.**

# %%
# Import libraries

import os
import numpy as np
import pandas as pd
from google.colab import drive

# %%
# Load the data and read the first few lines of data

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Yang_DSCI441_Final_Project')
Credit_data = pd.read_csv("dataset1_creditcard.csv")
Credit_data.head()
# Out:
# Mounted at /content/drive
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# The shape of Credit_data
Credit_data.shape
# Out:
# (284807, 31)

# %%
# Sample n rows randomly from the Credit_data
n = 180000  # specify the number of rows you want to select
sampled_Credit_data = Credit_data.sample(n)# Save the sampled data to a CSV file
sampled_Credit_data.to_csv('/content/drive/MyDrive/Yang_DSCI441_Final_Project/sampled_Credit_data.csv', index=False)

# %%
Credit_data1 = pd.read_csv("sampled_Credit_data-2.csv")
Credit_data1.head()
# Out:
#        Time         V1        V2        V3        V4        V5        V6  \
# 0  136495.0   1.891340 -0.941703 -0.465693  0.822444 -1.053182 -0.418160
# 1   38571.0  -0.429903  0.167311  0.647957 -1.936330  0.660004 -0.624739
# 2   26672.0  -1.204670  0.074550  1.778099  1.433339  0.167659  0.349178
# 3  156508.0 -11.521712  9.654525 -9.368721 -0.983806 -6.521962 -2.304209
# 4   79672.0  -1.406149 -0.054912  2.723919 -0.979521  0.449242  0.560431
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -0.599302 -0.038268  0.063975  ... -0.713578 -1.674146  0.424086 -0.271521
# 1  0.575645  0.100204  0.642102  ...  0.125645  0.444372 -0.290911 -0.292411
# 2  0.858258  0.177383 -0.940010  ...  0.165821  0.247312  0.166215  0.231063
# 3 -6.099734  8.252839  0.976392  ...  0.536635  0.732827  1.127417 -0.059780
# 4 -0.245460  0.676369  0.245946  ...  0.086798  0.154142 -0.159691 -0.285275
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
Credit_data1.shape
# Out:
# (180000, 31)
